# %% [markdown]
# # 01. Importing Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
#define the path for the data
path = r'/Users/niphomkhwane/Documents/A_Data Analytics/Module 4 - Python/Instacart Basket Analysis/'

# %%
#import the prior order data
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# import the orders data
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_cleaned.csv'), index_col = False)
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0           0   2539329        1             1                  2
# 1           1   2398795        1             2                  3
# 2           2    473747        1             3                  3
# 3           3   2254736        1             4                  4
# 4           4    431534        1             5                  4
#
#    order_hour_of_day  days_since_prior_order  first_time_order
# 0                  8                     NaN              True
# 1                  7                    15.0             False
# 2                 12                    21.0             False
# 3                  7                    29.0             False
# 4                 15                    28.0             False

# %%
#drop extra column in the data
df_ords = df_ords.drop(columns = ['Unnamed: 0'])

# %%
#check for missing values
df_ords_prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
df_ords_prior_dups = df_ords_prior[df_ords_prior.duplicated()]
df_ords_prior_dups
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  first_time_order
# 0                     NaN              True
# 1                    15.0             False
# 2                    21.0             False
# 3                    29.0             False
# 4                    28.0             False

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#merge the two df's
df_ords_merged = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)
print(df_ords_merged)
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  first_time_order  \
# 0                         8                     NaN              True
# 1                         8                     NaN              True
# ...

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_time_order  product_id  add_to_cart_order  \
# 0                     NaN              True         196                  1
# 1                     NaN              True       14084                  2
# 2                     NaN              True       12427                  3
# 3                     NaN              True       26088                  4
# 4                     NaN              True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_large

# %%
df_merged_large.shape
# Out:
# (32434489, 11)

# %%
#export the data into a pickle format
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # 03. More Wrangling

# %%
#check for null values
df_ords_prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
#check if there are any mixed types in the data
for col in df_ords_prior.columns.tolist():
  mix = (df_ords_prior[[col]].applymap(type) != df_ords_prior[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords_prior[mix]) > 0:
    print (col)

# %%
#chek for duplicates
df_ords_prior_dups = df_ords_prior[df_ords_prior.duplicated()]
df_ords_prior_dups
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
