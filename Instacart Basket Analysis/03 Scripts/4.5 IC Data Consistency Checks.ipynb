# %% [markdown]
# # 01. Importing Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
path = r'/Users/niphomkhwane/Documents/A_Data Analytics/Module 4 - Python/Instacart Basket Analysis/'

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '4.3 IC products.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order
# 0                  2                  8                     NaN
# 1                  3                  7                    15.0
# 2                  3                 12                    21.0
# 3                  4                  7                    29.0
# 4                  4                 15                    28.0

# %%
df_ords['order_day_of_week'] = df_ords['order_day_of_week'].astype('int64')

# %%
df_ords = df_ords.drop(columns = ['Unnamed: 0.1'])
df_ords = df_ords.drop(columns = ['Unnamed: 0'])

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_nan = df_prods[df_prods['product_name'].isnull()== True]
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# # 03. Task

# %%
#pull the descriptive statistic
df_ords.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %%
df_ords.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_ords.shape
#
# NameError: name 'df_ords' is not defined

# %%
#The data looks fine. values in the descriptive statistic table seem to match the expected out of each column

# %%
#check if there are any mixed types in the data
for col in df_ords.columns.tolist():
  mix = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[mix]) > 0:
    print (col)

# %%
#None of the columns have mix data types in them

# %%
#check for missing values
df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# order_number                   0
# order_day_of_week              0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
#there 206 209 missing values for the days_since_prior_order. 
#I think this is probably based on the first time orders of customers. 
#Therefore this is valid. For this I would create a support column called first_time_order and have a boolean value.

# %%
#address missing values
df_ords_nan = df_ords[df_ords['days_since_prior_order'].isnull()== True]
df_ords_nan
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 11        2168274        2             1                  2
# 26        1374495        3             1                  1
# 39        3343014        4             1                  6
# 45        2717275        5             1                  3
# ...           ...      ...           ...                ...
# 3420930    969311   206205             1                  4
# 3420934   3189322   206206             1                  3
# 3421002   2166133   206207             1                  6
# 3421019   2227043   206208             1                  1
# 3421069   3154581   206209             1                  3
#
#          order_hour_of_day  days_since_prior_order  first_time_order
# 0                        8                     NaN              True
# 11                      11                     NaN              True
# ...

# %%
#address missing values
df_ords_first_time = pd.DataFrame(df_ords)
print(df_ords_first_time)
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
df_ords['first_time_order']=df_ords['days_since_prior_order'].isnull()

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_prior_order  first_time_order
# 0                        8                     NaN              True
# 1                        7                    15.0             False
# ...

# %%
true_count = df_ords['first_time_order'].sum()
print(true_count)
#I've created a new column in the df that return a true value if days_since_prior_order is null
#I've checked to see if the values that return "true" matches with the number that of null values in days_since_prior_order
# Out:
# 206209

# %%
#Check for duplicates
df_ords_dups = df_ords[df_ords.duplicated()]
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_prior_order, first_time_order]
# Index: []

# %%
#The only duplicates found are in the new created column. However these are not true duplicates as none of the rows
#are duplicated
#I have not applied any method as there are no duplicates in the df

# %% [markdown]
# # 04. Exporting Data

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data','products_cleaned.csv'))

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data','orders_cleaned.csv'))
